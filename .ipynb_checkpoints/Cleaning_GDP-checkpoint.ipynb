# %%
# Import dependencies
import pandas as pd
import numpy as np
import plotly.express as plt

# %%
# import dataset
gdp_df = pd.read_csv('Resources/US_GDPbyState.csv')
gdp_df
# Out:
#               GeoName IndustryClassification  \
# 0     United States *                    ...
# 1     United States *                    ...
# 2     United States *                     11
# 3     United States *                111-112
# 4     United States *                113-115
# ...               ...                    ...
# 4783          Wyoming              42, 44-45
# 4784          Wyoming              22, 48-49
# 4785          Wyoming              31-33, 51
# 4786          Wyoming                    ...
# 4787          Wyoming                    ...
#
#                                        Description                  Unit  \
# 0                               All industry total  Thousands of dollars
# 1                               Private industries  Thousands of dollars
# 2       Agriculture, forestry, fishing and hunting  Thousands of dollars
# 3                                            Farms  Thousands of dollars
# ...

# %%
# Group by All Industry Total
gdp_df2 = gdp_df.loc[gdp_df['Description'] == "All industry total"]
gdp_df2
# Out:
#                    GeoName IndustryClassification         Description  \
# 0          United States *                    ...  All industry total
# 96                 Alabama                    ...  All industry total
# 188                 Alaska                    ...  All industry total
# 280                Arizona                    ...  All industry total
# 372               Arkansas                    ...  All industry total
# 464             California                    ...  All industry total
# 556               Colorado                    ...  All industry total
# 648            Connecticut                    ...  All industry total
# 740               Delaware                    ...  All industry total
# 832   District of Columbia                    ...  All industry total
# 924                Florida                    ...  All industry total
# 1016               Georgia                    ...  All industry total
# ...

# %%
# Drop unneccessary columns
gdp_df2 = gdp_df2.drop(['IndustryClassification', 'Description', 'Unit'], axis = 1)
gdp_df2
# Out:
#                    GeoName        1997        1998        1999        2000  \
# 0          United States *  3286531000  3384012000  3592863000  3733598000
# 96                 Alabama    37247871    39368055    41513658    42583368
# 188                 Alaska    11061328     9388659     9690070    10455709
# 280                Arizona    53776045    57020794    62895447    62781317
# 372               Arkansas    23315960    23736909    25718358    25974140
# 464             California   431069388   453030898   487837764   509912047
# 556               Colorado    52989433    57765105    62638825    66474953
# 648            Connecticut    50568520    51906772    53755314    59834228
# 740               Delaware    16293486    18697289    20725145    22478806
# 832   District of Columbia    14800959    15341732    16243372    16094689
# 924                Florida   142316948   147761064   159175918   168100246
# ...

# %%
# Stack Years into a column
gdp_df3 = gdp_df2.set_index(['GeoName']).stack()\
    .reset_index(name = "GDP").rename(columns={'level_1':'Year', 'GeoName':'State'})
gdp_df3
# Out:
#                 State  Year         GDP
# 0     United States *  1997  3286531000
# 1     United States *  1998  3384012000
# 2     United States *  1999  3592863000
# 3     United States *  2000  3733598000
# 4     United States *  2001  3866604000
# ...               ...   ...         ...
# 1243          Wyoming  2016    15164898
# 1244          Wyoming  2017    15976363
# 1245          Wyoming  2018    17122283
# 1246          Wyoming  2019    16978835
# 1247          Wyoming  2020    15469645
#
# [1248 rows x 3 columns]

# %%
# Replace "United States *" with "United States"
gdp_df3['State'] = gdp_df3['State'].str.replace(r'United States \*', r'United States')

gdp_df3
# Out:
# C:\ProgramData\Anaconda3\envs\mlenv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#               State  Year         GDP
# 0     United States  1997  3286531000
# 1     United States  1998  3384012000
# 2     United States  1999  3592863000
# 3     United States  2000  3733598000
# 4     United States  2001  3866604000
# ...             ...   ...         ...
# 1243        Wyoming  2016    15164898
# 1244        Wyoming  2017    15976363
# 1245        Wyoming  2018    17122283
# 1246        Wyoming  2019    16978835
# 1247        Wyoming  2020    15469645
#
# [1248 rows x 3 columns]

# %%
# Multiply GDP by 1000 (in excel) to get actual GDP numbers
gdp_df3.to_csv('Resources/US_GDPbyState1.csv')

# %%
# Re-import data
gdp_df4 = pd.read_csv('Resources/US_GDPbyState1.csv', index_col = 'State')
gdp_df4
# Out:
#                Year           GDP
# State
# United States  1997  3.286530e+12
# United States  1998  3.384010e+12
# United States  1999  3.592860e+12
# United States  2000  3.733600e+12
# United States  2001  3.866600e+12
# ...             ...           ...
# Wyoming        2016  1.516490e+10
# Wyoming        2017  1.597636e+10
# Wyoming        2018  1.712228e+10
# Wyoming        2019  1.697884e+10
# Wyoming        2020  1.546964e+10
#
# [1248 rows x 2 columns]
