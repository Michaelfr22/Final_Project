# %%
# Import dependencies
import pandas as pd
import numpy as np
import plotly.express as plt

# %%
# import dataset
gdp_df = pd.read_csv('Resources/US_GDPbyState.csv')
gdp_df
# Out:
#                                                 GeoFIPS          GeoName  \
# 0                                               "00000"  United States *
# 1                                               "00000"  United States *
# 2                                               "00000"  United States *
# 3                                               "00000"  United States *
# 4                                               "00000"  United States *
# ...                                                 ...              ...
# 5523                                            "98000"         Far West
# 5524              Note: See the included footnote file.              NaN
# 5525                SAGDP7N: Gross operating surplus 1/              NaN
# 5526  Last updated: October 1, 2021-- new statistics...              NaN
# 5527  Source: U.S. Department of Commerce / Bureau o...              NaN
#
#      Region TableName  LineCode IndustryClassification  \
# ...
